# %% [markdown]
# ### TF2 Unboxing Simulator Demo ###

# %%
import tf2_unbox_simulator

# %%
unbox_simulator(100,1000000)
# Out:
# Unboxing Results based on your  1000000  Unboxing Simulation with  100  Cases:
# Unusual Occurence Count:  Counter({0: 520983, 1: 340454, 2: 110459, 3: 23822, 4: 3751, 5: 469, 6: 59, 7: 2, 8: 1})
# Chance to end up with 0 unusual from your  100  unboxes is 52.1 %
# Average Number of Unusuals Unboxed:  0.65  out of  100  cases
# Minimum Number of Unusuals Unboxed:  0  out of  100  cases
# Maximum Number of Unusuals Unboxed:  8  out of  100  cases
# See the full distribution in the below chart:
# ...
